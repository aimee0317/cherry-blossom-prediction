# %% [markdown]
# ## Missing data imputation

# %%
import numpy as np
import pandas as pd 
from sklearn.impute import KNNImputer
from sklearn.model_selection import cross_val_score, cross_validate, train_test_split
from sklearn.neighbors import KNeighborsClassifier, KNeighborsRegressor
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import (
    OneHotEncoder,
    OrdinalEncoder,
    StandardScaler,
)

from sklearn.preprocessing import StandardScaler
from sklearn.compose import ColumnTransformer, make_column_transformer

# %% [markdown]
# ### Load the processed data set with missing values and filter to extract data after year 1950

# %%
data = pd.read_csv("../data/processed/processed_data.csv")
filtered_data = data[data['year'] >= 1950]
filtered_data
# Out:
#                id             location      country          city        lat  \
# 0     JAM00047918   Japan/Ishigakijima        Japan  Ishigakijima  24.336667
# 1     JAM00047918   Japan/Ishigakijima        Japan  Ishigakijima  24.336667
# 2     JAM00047918   Japan/Ishigakijima        Japan  Ishigakijima  24.336667
# 3     JAM00047918   Japan/Ishigakijima        Japan  Ishigakijima  24.336667
# 4     JAM00047918   Japan/Ishigakijima        Japan  Ishigakijima  24.336667
# ...           ...                  ...          ...           ...        ...
# 7023  GME00127786  Switzerland/Liestal  Switzerland       Liestal  47.481400
# 7024  GME00127786  Switzerland/Liestal  Switzerland       Liestal  47.481400
# 7025  GME00127786  Switzerland/Liestal  Switzerland       Liestal  47.481400
# 7026  GME00127786  Switzerland/Liestal  Switzerland       Liestal  47.481400
# 7027  GME00127786  Switzerland/Liestal  Switzerland       Liestal  47.481400
#
#             long    alt  year  bloom_date  bloom_doy       tmax      tmin  \
# 0     124.164444    5.7  1962  1962-02-20         51        NaN       NaN
# 1     124.164444    5.7  1963  1963-02-15         46        NaN       NaN
# 2     124.164444    5.7  1967  1967-02-13         44        NaN       NaN
# 3     124.164444    5.7  1971  1971-02-10         41        NaN       NaN
# 4     124.164444    5.7  1972  1972-02-20         51        NaN       NaN
# ...          ...    ...   ...         ...        ...        ...       ...
# 7023    7.730519  350.0  2017  2017-03-26         85  16.618082  6.177260
# 7024    7.730519  350.0  2018  2018-04-08         98  17.635616  7.103836
# 7025    7.730519  350.0  2019  2019-03-27         86  17.057534  6.315890
# 7026    7.730519  350.0  2020  2020-03-17         77  17.612842  6.630055
# 7027    7.730519  350.0  2021  2021-03-28         87  15.708219  5.805753
#
#           prcp  agdd_winter  tmax_winter  tmin_winter  prcp_winter  \
# 0          NaN          NaN          NaN          NaN          NaN
# 1          NaN          NaN          NaN          NaN          NaN
# 2          NaN          NaN          NaN          NaN          NaN
# 3          NaN          NaN          NaN          NaN          NaN
# 4          NaN          NaN          NaN          NaN          NaN
# ...        ...          ...          ...          ...          ...
# 7023  2.740822       235.55     5.344240    -1.678610    15.421659
# 7024  2.196438       337.85     6.214555     0.563710    27.304147
# 7025  2.327945       374.60     7.906413     0.278994    20.287634
# 7026  2.223224       475.65     9.360289     1.146607    21.002225
# 7027  3.298630       372.05     7.178418     0.439171    33.856375
#
#       co2_percapita  co2_emission
# 0            3.0680   292864430.0
# 1            3.3700   324835463.0
# 2            4.8532   489307430.0
# 3            7.4844   796544280.0
# 4            7.8922   852170216.0
# ...             ...           ...
# 7023         4.5155    38182513.0
# 7024         4.3243    36867631.0
# 7025         4.2766    36741865.0
# 7026         3.7319    32298333.0
# 7027            NaN           NaN
#
# [6182 rows x 19 columns]

# %% [markdown]
# ### Set up the KNNimputer and select columns used for imputations

# %%
imputer = KNNImputer(n_neighbors=10, weights='distance', metric='nan_euclidean')

# %%
for_imputation = [
    "lat",
    "long",
    "alt",
    "tmax",
    "tmin",
    "prcp",
    "agdd_winter",
    "tmax_winter",
    "tmin_winter",
    "prcp_winter",
    "co2_percapita",
]

others = ["country", "city", "year", "bloom_doy"]

# %%
for_imputation_data = filtered_data[for_imputation]
for_imputation_data
# Out:
#             lat        long    alt       tmax      tmin      prcp  \
# 0     24.336667  124.164444    5.7        NaN       NaN       NaN
# 1     24.336667  124.164444    5.7        NaN       NaN       NaN
# 2     24.336667  124.164444    5.7        NaN       NaN       NaN
# 3     24.336667  124.164444    5.7        NaN       NaN       NaN
# 4     24.336667  124.164444    5.7        NaN       NaN       NaN
# ...         ...         ...    ...        ...       ...       ...
# 7023  47.481400    7.730519  350.0  16.618082  6.177260  2.740822
# 7024  47.481400    7.730519  350.0  17.635616  7.103836  2.196438
# 7025  47.481400    7.730519  350.0  17.057534  6.315890  2.327945
# 7026  47.481400    7.730519  350.0  17.612842  6.630055  2.223224
# 7027  47.481400    7.730519  350.0  15.708219  5.805753  3.298630
#
#       agdd_winter  tmax_winter  tmin_winter  prcp_winter  co2_percapita
# 0             NaN          NaN          NaN          NaN         3.0680
# 1             NaN          NaN          NaN          NaN         3.3700
# 2             NaN          NaN          NaN          NaN         4.8532
# 3             NaN          NaN          NaN          NaN         7.4844
# 4             NaN          NaN          NaN          NaN         7.8922
# ...           ...          ...          ...          ...            ...
# 7023       235.55     5.344240    -1.678610    15.421659         4.5155
# 7024       337.85     6.214555     0.563710    27.304147         4.3243
# 7025       374.60     7.906413     0.278994    20.287634         4.2766
# 7026       475.65     9.360289     1.146607    21.002225         3.7319
# 7027       372.05     7.178418     0.439171    33.856375            NaN
#
# [6182 rows x 11 columns]

# %%
impute_df = pd.DataFrame(imputer.fit_transform(for_imputation_data),columns = for_imputation_data.columns).reset_index()
impute_df
# Out:
#       index        lat        long    alt       tmax       tmin       prcp  \
# 0         0  24.336667  124.164444    5.7  23.800000  21.050400  21.970455
# 1         1  24.336667  124.164444    5.7  23.800000  21.050400  21.970455
# 2         2  24.336667  124.164444    5.7  23.800000  21.050400  21.970455
# 3         3  24.336667  124.164444    5.7  23.800000  21.050400  21.970455
# 4         4  24.336667  124.164444    5.7  23.800000  21.050400  21.970455
# ...     ...        ...         ...    ...        ...        ...        ...
# 6177   6177  47.481400    7.730519  350.0  16.618082   6.177260   2.740822
# 6178   6178  47.481400    7.730519  350.0  17.635616   7.103836   2.196438
# 6179   6179  47.481400    7.730519  350.0  17.057534   6.315890   2.327945
# 6180   6180  47.481400    7.730519  350.0  17.612842   6.630055   2.223224
# 6181   6181  47.481400    7.730519  350.0  15.708219   5.805753   3.298630
#
#       agdd_winter  tmax_winter  tmin_winter  prcp_winter  co2_percapita
# 0           22.35    17.800000    15.018750    98.400000       3.068000
# 1           22.35    17.800000    15.018750    98.400000       3.370000
# 2           22.35    17.800000    15.018750    98.400000       4.853200
# 3           22.35    17.800000    15.018750    98.400000       7.484400
# 4           22.35    17.800000    15.018750    98.400000       7.892200
# ...           ...          ...          ...          ...            ...
# 6177       235.55     5.344240    -1.678610    15.421659       4.515500
# 6178       337.85     6.214555     0.563710    27.304147       4.324300
# 6179       374.60     7.906413     0.278994    20.287634       4.276600
# 6180       475.65     9.360289     1.146607    21.002225       3.731900
# 6181       372.05     7.178418     0.439171    33.856375       2.381433
#
# [6182 rows x 12 columns]

# %%
others_df = filtered_data[others].reset_index()
others_df
# Out:
#       index      country          city  year  bloom_doy
# 0         0        Japan  Ishigakijima  1962         51
# 1         1        Japan  Ishigakijima  1963         46
# 2         2        Japan  Ishigakijima  1967         44
# 3         3        Japan  Ishigakijima  1971         41
# 4         4        Japan  Ishigakijima  1972         51
# ...     ...          ...           ...   ...        ...
# 6177   7023  Switzerland       Liestal  2017         85
# 6178   7024  Switzerland       Liestal  2018         98
# 6179   7025  Switzerland       Liestal  2019         86
# 6180   7026  Switzerland       Liestal  2020         77
# 6181   7027  Switzerland       Liestal  2021         87
#
# [6182 rows x 5 columns]

# %% [markdown]
# ### Put together the final data set and export to csv

# %%
final_df = pd.concat([others_df, impute_df], axis = 1)
final_df = final_df.drop(columns = ['index'])

# %%
final_df
# Out:
#           country          city  year  bloom_doy        lat        long  \
# 0           Japan  Ishigakijima  1962         51  24.336667  124.164444
# 1           Japan  Ishigakijima  1963         46  24.336667  124.164444
# 2           Japan  Ishigakijima  1967         44  24.336667  124.164444
# 3           Japan  Ishigakijima  1971         41  24.336667  124.164444
# 4           Japan  Ishigakijima  1972         51  24.336667  124.164444
# ...           ...           ...   ...        ...        ...         ...
# 6177  Switzerland       Liestal  2017         85  47.481400    7.730519
# 6178  Switzerland       Liestal  2018         98  47.481400    7.730519
# 6179  Switzerland       Liestal  2019         86  47.481400    7.730519
# 6180  Switzerland       Liestal  2020         77  47.481400    7.730519
# 6181  Switzerland       Liestal  2021         87  47.481400    7.730519
#
#         alt       tmax       tmin       prcp  agdd_winter  tmax_winter  \
# 0       5.7  23.800000  21.050400  21.970455        22.35    17.800000
# 1       5.7  23.800000  21.050400  21.970455        22.35    17.800000
# 2       5.7  23.800000  21.050400  21.970455        22.35    17.800000
# 3       5.7  23.800000  21.050400  21.970455        22.35    17.800000
# 4       5.7  23.800000  21.050400  21.970455        22.35    17.800000
# ...     ...        ...        ...        ...          ...          ...
# 6177  350.0  16.618082   6.177260   2.740822       235.55     5.344240
# 6178  350.0  17.635616   7.103836   2.196438       337.85     6.214555
# 6179  350.0  17.057534   6.315890   2.327945       374.60     7.906413
# 6180  350.0  17.612842   6.630055   2.223224       475.65     9.360289
# 6181  350.0  15.708219   5.805753   3.298630       372.05     7.178418
#
#       tmin_winter  prcp_winter  co2_percapita
# 0       15.018750    98.400000       3.068000
# 1       15.018750    98.400000       3.370000
# 2       15.018750    98.400000       4.853200
# 3       15.018750    98.400000       7.484400
# 4       15.018750    98.400000       7.892200
# ...           ...          ...            ...
# 6177    -1.678610    15.421659       4.515500
# 6178     0.563710    27.304147       4.324300
# 6179     0.278994    20.287634       4.276600
# 6180     1.146607    21.002225       3.731900
# 6181     0.439171    33.856375       2.381433
#
# [6182 rows x 15 columns]

# %%
final_df.to_csv('./processed/clean_data.csv', index=False)

# %% [markdown]
# ### Sanity Check

# %%
final_df.isna().sum()
# Out:
# country          0
# city             0
# year             0
# bloom_doy        0
# lat              0
# long             0
# alt              0
# tmax             0
# tmin             0
# prcp             0
# agdd_winter      0
# tmax_winter      0
# tmin_winter      0
# prcp_winter      0
# co2_percapita    0
# dtype: int64
